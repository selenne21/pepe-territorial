# %%
import pandas as pd

# %%
df=pd.read_parquet("C:\\PEPE_TERRITORIAL\\data\\revisar.parquet")

# %%
df.columns
# Out:
# Index(['Año', 'codigo_alt', 'Entidad', 'Tipo de Entidad', 'Departamento',
#        'col_1', 'col_2', 'col_3', 'col_4', 'col_5', 'col_6', 'col_7', 'col_8',
#        'col_9', 'col_10', 'TotalRecaudo', 'clasificacion_ofpuj', 'clas_gen',
#        'IPC', 'TotalRecaudo_real', 'Habitantes'],
#       dtype='object')

# %%
df
# Out:
#        Año  codigo_alt        Entidad Tipo de Entidad        Departamento  \
# 0     2014       19050        Argelia       Municipio               Cauca
# 1     2012       73000         Tolima    Departamento              Tolima
# 2     2023       66075         Balboa       Municipio           Risaralda
# 3     2018       52621  Roberto Payán       Municipio              Nariño
# 4     2018        5045       Apartadó       Municipio           Antioquia
# ...    ...         ...            ...             ...                 ...
# 4995  2021        5400       La Unión       Municipio           Antioquia
# 4996  2020        5264     Entrerrios       Municipio           Antioquia
# 4997  2019       52480         Nariño       Municipio              Nariño
# 4998  2017       54109     Bucarasica       Municipio  Norte de Santander
# 4999  2019       68370         Jordán       Municipio           Santander
#
#                  col_1                col_2  \
# ...

# %%
df[["codigo_alt","Habitantes","Año"]].drop_duplicates().to_parquet("pop.parquet",index=False)
