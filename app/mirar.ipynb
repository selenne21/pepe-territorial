# %%
import pandas as pd

# %%
df=pd.read_parquet("C:\PEPE_TERRITORIAL\data\ingresos_ipc_pop.parquet")

# %%
df
# Out:
#          Año Tipo de Entidad Departamento  codigo_alt   Entidad  \
# 0       2012    Departamento     Amazonas       91000  Amazonas
# 1       2012    Departamento     Amazonas       91000  Amazonas
# 2       2012    Departamento     Amazonas       91000  Amazonas
# 3       2012    Departamento     Amazonas       91000  Amazonas
# 4       2012    Departamento     Amazonas       91000  Amazonas
# ...      ...             ...          ...         ...       ...
# 222885  2024       Municipio      Vichada       99773  Cumaribo
# 222886  2024       Municipio      Vichada       99773  Cumaribo
# 222887  2024       Municipio      Vichada       99773  Cumaribo
# 222888  2024       Municipio      Vichada       99773  Cumaribo
# 222889  2024       Municipio      Vichada       99773  Cumaribo
#
#                    clas_gen  \
# 0       Recursos de capital
# 1       Recursos de capital
# 2          Recursos propios
# 3          Recursos propios
# 4          Recursos propios
# ...
